# %%
import pandas as pd
import geopandas as gpd

# %%
building_footprint = gpd.read_file('um-building-footprint.geojson')
print(building_footprint.head())
# Out:
#    OBJECTID loc_Campus_descr loc_SubCampus_descr loc_MainCampus  Status
# 0         1        Ann Arbor        North Campus           Main  Active  \
# 1         2        Ann Arbor        North Campus           Main  Active
# 2         3        Ann Arbor        North Campus           Main  Active
# 3         4        Ann Arbor      Central Campus           Main  Active
# 4         6        Ann Arbor      Medical Campus           Main  Active
#
#   Ownership PanelType                               ObjectName Building_Type
# 0       Own  Building                 NCRC  B500 (Underground)         BLDGU  \
# 1       Own  Building                             NCRC Bldg 15         BLDGU
# 2       Own  Building                             NCRC Bldg 23         BLDGU
# 3       Own  Building          Central Campus Support Facility         BLDGU
# 4       Own  Building  Cardiovascular Center Parking Structure         PARKU
#
#   loc_ObjectNum   created_user   created_date last_edited_user
# 0       1005280  brimcel_umich  1751976683021    brimcel_umich  \
# 1       1005255  brimcel_umich  1751976683021    brimcel_umich
# 2       1005261  brimcel_umich  1751976683021    brimcel_umich
# 3       1005379  brimcel_umich  1751976683021    brimcel_umich
# 4       1005146  brimcel_umich  1751976683021    brimcel_umich
#
#    last_edited_date                              GlobalID  SUBTYPE
# 0     1751976683021  5022191f-82a9-4b0d-9ae3-8fe1fac098cf        3  \
# 1     1751976683021  ff531986-1ca8-40a8-aff9-a3ae7b7670d9        3
# 2     1751976683021  492056f7-f411-46da-8094-f323a85481a3        3
# 3     1751976683021  3a10f37e-15f9-41cf-bfb6-8027c21d1bad        3
# 4     1751976683021  a314aa07-9fc4-40aa-9e73-18c9827a08e2        3
#
#     Shape__Area  Shape__Length
# 0  15083.046875    1214.576194  \
# 1   5937.982910     322.868746
# 2  10717.561279     643.277263
# 3     87.915283      39.349791
# 4  75928.744141    1362.263516
#
#                                             geometry
# 0  POLYGON ((-83.70362 42.2999, -83.70362 42.2999...
# 1  POLYGON ((-83.7067 42.30023, -83.7067 42.30004...
# 2  POLYGON ((-83.70674 42.29968, -83.70674 42.299...
# 3  POLYGON ((-83.7354 42.27905, -83.7354 42.27907...
# 4  POLYGON ((-83.73085 42.28281, -83.73082 42.282...

# %%
building_footprint.loc[building_footprint['ObjectName'] == "Weiser Hall", "AI_resource"] = True

# %%
building_footprint.to_file("um-building-footprint-edited.geojson", driver="GeoJSON")
