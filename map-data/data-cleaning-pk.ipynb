# %%
import pandas as pd
import geopandas as gpd

# %%
building_footprint = gpd.read_file('um-building-footprint-edited.geojson')
building_footprint.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1045 entries, 0 to 1044
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   building_name  963 non-null    object
#  1   building_id    1045 non-null   object
#  2   campus         1045 non-null   object
#  3   sub_campus     1045 non-null   object
#  4   is_resource    1045 non-null   bool
#  5   category       14 non-null     object
#  6   audience       14 non-null     object
#  7   geometry       1045 non-null   geometry
# dtypes: bool(1), geometry(1), object(6)
# memory usage: 58.3+ KB

# %%
building_footprint['service'] = [[] for _ in range(len(building_footprint))]
building_footprint.at[building_footprint[building_footprint['building_name'] == "Weiser Hall"].index[0],
                      "service"] = ["Consulting & Support", "Funding & Project Development", "Research & Methods"]
building_footprint.loc[building_footprint['building_name'] == "Weiser Hall", "email"] = "midas-research@umich.edu"

building_footprint.loc[building_footprint['building_name'] == "Weiser Hall", "url"] = "https://midas.umich.edu/"

# %%
building_footprint[building_footprint['building_name'] == "NCRC Bldg 520"]["category"].values
# Out:
# array(['Applied & Domain Focused Research; Funding & Project Development'],
#       dtype=object)

# %%
building_footprint.to_file("um-building-footprint-edited.geojson", driver="GeoJSON")

# %%
building_footprint.building_id == '1005280'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1037    False
# 1038    False
# 1039    False
# 1040    False
# 1041    False
# Name: building_id, Length: 1042, dtype: bool

# %%
resources = pd.read_csv("resources.csv")

# %%
resources['building_id']
# Out:
# 0           NaN
# 1     1000145.0
# 2     1000204.0
# 3     1005282.0
# 4     1005281.0
# 5     1005276.0
# 6           NaN
# 7     1005092.0
# 8     1005574.0
# 9     1000193.0
# 10    1005276.0
# 11    1000166.0
# 12    1000193.0
# 13    1000145.0
# 14    1000197.0
# 15    1005101.0
# 16          NaN
# 17    1000165.0
# Name: building_id, dtype: float64
