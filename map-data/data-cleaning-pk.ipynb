# %%
import pandas as pd
import geopandas as gpd

# %%
building_footprint = gpd.read_file('um-building-footprint-edited.geojson')
building_footprint.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1042 entries, 0 to 1041
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   building_name  960 non-null    object
#  1   building_id    1017 non-null   object
#  2   campus         1042 non-null   object
#  3   sub_campus     1042 non-null   object
#  4   is_resource    1042 non-null   bool
#  5   org            2 non-null      object
#  6   description    2 non-null      object
#  7   address        2 non-null      object
#  8   service        1042 non-null   object
#  9   email          1 non-null      object
#  10  url            2 non-null      object
#  11  geometry       1042 non-null   geometry
# dtypes: bool(1), geometry(1), object(10)
# memory usage: 90.7+ KB

# %%
building_footprint.loc[building_footprint['building_name'] == "Weiser Hall", "org"] = "Michigan Institute for Data & AI in Society"
building_footprint.loc[building_footprint['building_name'] == "Weiser Hall", "description"] = "We are a university-wide organization that advances data science and artificial intelligence (AI) and enables their transformative use across a wide range of research domains for lasting scientific and societal impact. We support innovative research and collaboration and provide research resources, offer training for faculty and other researchers, host three postdoctoral training programs, and develop extensive research collaboration with academia, industry and government."
building_footprint.loc[building_footprint['building_name'] == "Weiser Hall", "address"] = "500 Church Street, Ann Arbor MI 48109-1042"
building_footprint['service'] = [[] for _ in range(len(building_footprint))]
building_footprint.at[building_footprint[building_footprint['building_name'] == "Weiser Hall"].index[0],
                      "service"] = ["Consulting & Support", "Funding & Project Development", "Research & Methods"]
building_footprint.loc[building_footprint['building_name'] == "Weiser Hall", "email"] = "midas-research@umich.edu"

building_footprint.loc[building_footprint['building_name'] == "Weiser Hall", "url"] = "https://midas.umich.edu/"



building_footprint.loc[building_footprint['building_name'] == "NCRC Bldg 520", "org"] = "e-HAIL: E-Health & Artificial Intelligence"
building_footprint.loc[building_footprint['building_name'] == "NCRC Bldg 520", "description"] = "e-HAIL is a joint Michigan Medicine and College of Engineering initiative that aims to make U-M a premier hub for research that innovates in health through AI. Our focus is on collaboration, grant development, and infrastructure to support a multi-disciplinary approach to innovations in healthcare and AI/ML methodologies.The initiative provides several opportunities for researchers to connect and learn from others operating at the intersection of AI and health.We provide concrete support for preparing grant applications, including finding collaborators, grant writing assistance, and hiring student support."
building_footprint.loc[building_footprint['building_name'] == "NCRC Bldg 520", "address"] = "2800 Plymouth Rd, Ann Arbor, MI 48109"
building_footprint.at[building_footprint[building_footprint['building_name'] == "NCRC Bldg 520"].index[0], 
    "service"] = ["Applied & Domain Focused Research", "Funding & Project Development"]
building_footprint.loc[building_footprint['building_name'] == "NCRC Bldg 520", "url"] = "https://e-hail.umich.edu/"

# %%
building_footprint[building_footprint['building_name'] == "NCRC Bldg 520"]
# Out:
#      building_name building_id     campus    sub_campus  is_resource
# 496  NCRC Bldg 520     1005281  Ann Arbor  North Campus         True  \
#
#                                               geometry
# 496  POLYGON ((-83.70253 42.30066, -83.70253 42.300...  \
#
#                                             org
# 496  e-HAIL: E-Health & Artificial Intelligence  \
#
#                                            description
# 496  e-HAIL is a joint Michigan Medicine and Colleg...  \
#
#                                    address
# 496  2800 Plymouth Rd, Ann Arbor, MI 48109  \
#
#                                                service email
# 496  [Applied & Domain Focused Research, Funding & ...   NaN  \
#
#                            url
# 496  https://e-hail.umich.edu/

# %%
building_footprint.to_file("um-building-footprint-edited.geojson", driver="GeoJSON")

# %%
building_footprint.building_id == '1005280'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1037    False
# 1038    False
# 1039    False
# 1040    False
# 1041    False
# Name: building_id, Length: 1042, dtype: bool

# %%
resources = pd.read_csv("resources.csv")

# %%
resources
# Out:
#     building_id                                      resource_name
# 0           NaN                        Advanced Research Computing  \
# 1     1000145.0  Data Science for Dynamic Intervention Decision...
# 2     1000204.0  Statistical Analysis of Biomedical and Educati...
# 3     1005282.0  Clinical & Health Research Dissemination & Imp...
# 4     1005281.0         e-HAIL: E-Health & Artificial Intelligence
# 5     1005276.0                     AI & Digital Health Innovation
# 6           NaN                Michigan Alzheimer's Disease Center
# 7     1005092.0                                             AI Lab
# 8     1005574.0  Michigan Institute for Computational Discovery...
# 9     1000193.0    Arts Research: Incubation & Acceleration (ARIA)
# 10    1005276.0                    Center for Global Health Equity
# 11    1000166.0  Michigan Center for Applied and Interdisciplin...
# 12    1000193.0                                    Bold Challenges
# ...
